# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv(r"titanic_train.csv")

# %%
print(plt.style.available)
# Out:
# ['seaborn-white', 'seaborn-dark-palette', 'dark_background', 'seaborn-ticks', 'seaborn-colorblind', 'seaborn-talk', 'tableau-colorblind10', 'seaborn-pastel', 'seaborn-poster', 'seaborn-deep', 'seaborn-paper', 'seaborn', 'fivethirtyeight', 'seaborn-muted', 'classic', 'bmh', 'grayscale', 'fast', 'seaborn-darkgrid', 'seaborn-dark', 'ggplot', 'seaborn-whitegrid', 'Solarize_Light2', 'seaborn-notebook', '_classic_test', 'seaborn-bright']

# %%
plt.style.use("seaborn-white")

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %% [raw]
# plt.figure(figsize = (10,4)) #to set the figure size
# plt.style.use("ggplot")
# plt.title("Title")
# plt.xlabel("Hrs")
# plt.ylabel("Frequency")
# plt.xticks(rotation = -45)
# plt.yticks(rotation = -30)
# plt.legend()
# plt.axis([0,50,0,40])
# plt.xlim(0,50)
# plt.ylim(0,40)
# plt.show() - to ignore any text

# %%
#xticks(np.arange(12), calendar.month_name[1:13], rotation=20)

# %% [markdown]
# ### Line Plots

# %%
random_numbers = np.random.rand(10)
rn2 = np.random.randn(10)

# %%
plt.style.use("dark_background")

# %%
plt.figure(figsize=(10,4))
plt.plot(random_numbers, color = "g", ls = "-.", label = "line1", linewidth=1, marker = '1', alpha = .8) 
plt.plot(rn2, color = "lightblue", ls = "-", label = "line2", linewidth = 2,alpha = .5)
plt.legend()
#ls -, --, -., steps
#marker +,.,o, 1,2,3,4
#alpha indicates the transparency level
#label is to give labels in the legend
plt.axis([0,10, -2, 2])
#plt.xlim(0,10)
#plt.ylim(-2,2)
plt.show()

# %% [markdown]
# ### HISTOGRAMS

# %%
print(plt.colormaps())
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r
# ...

# %%
#?titanic.plot

# %%
titanic["Age"].plot(kind = "hist", colormap = "Greens_r") #using pandas library
plt.xlabel("Age")
plt.title("Histogram")
plt.show()

# %%
plt.hist(titanic["Fare"], bins = 10, color ="#93b6a7", alpha = .5 )
plt.show()

# %%
sns.distplot(titanic["Fare"], bins = 50, hist = False, )

# %%
sns.distplot(titanic["Fare"], bins = 50, hist = True, )

# %%
#in seaborn library we can put a  custom color pallette
pal_colors = ['#FF0000','#00FF00', '#0000FF' ]

# %%
sns.set(style = "whitegrid", palette="dark", font_scale=2)
#style options: darkgrid, whitegrid, dark, white, ticks

# %%
sns.boxplot(y = titanic["Fare"]) 
#color palettes in seaborndeep, muted, pastel, bright, dark, colorblind
#sns.boxplot(y = titanic["Fare"], palette="bright") 

plt.show()

# %%
titanic.Age.plot(kind = "box")

# %% [markdown]
# ### Transformations to handle the skewed distributions

# %%
#Fare is a right skewed
#Age is a normal distribution with some outliers - the outliers need to be imputed with some logical value Q3 + 1.5IQR 
# or Q1 - 1.5IQR

#to convert a right skewed distribution to a normal one, you need to try 
#transformations like: sq root, cube root, and incase of extreme right-skewness, try out logarithms
#to convert a left skewed distribution to a normal one, you need to try 
#out the transformations: sq, cube, power 4, and incase of extreme left skewness: try 10pow(x)

# %%
sns.distplot(np.log10(titanic["Fare"]+1), bins = 50, hist = True, )

# %%
sns.distplot((titanic["Fare"]**.5), bins = 50, hist = True, )

# %%
sns.distplot((titanic["Fare"]**(1/3)), bins = 50, hist = True, )

# %%
sns.distplot((titanic["Fare"]**(1/4)), bins = 50, hist = True, )

# %% [markdown]
# ----

# %% [markdown]
# ### Unvivariate Visualization of factor variables

# %%
sns.set(style = "whitegrid", palette="dark", font_scale=1)
#style options: darkgrid, whitegrid, dark, white, ticks

# %%
titanic.Sex.value_counts().plot(kind = "bar")
plt.xticks(rotation = -45)
plt.show()

# %%
freq_table = titanic.Sex.value_counts()
freq_table
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
plt.bar(x = freq_table.index, height = freq_table )
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# #### In every seaborn plot 2 syntaxes are aloud as mentioned below

# %%
sns.countplot(x = titanic.Sex)

# %%
sns.countplot(x = 'Sex', data = titanic)

# %% [markdown]
# #### Pie Charts

# %%
plt.pie(x = freq_table, explode = (.05, .05))
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ### Bivariate Relationships

# %% [markdown]
# #### CONT + FACTOR

# %%
titanic.groupby("Sex").Fare.mean().plot.bar()

# %%
titanic.Fare.isnull().sum()
# Out:
# 0

# %%
titanic.Fare[0] = np.nan
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic.Fare.isnull().sum()
# Out:
# 1

# %%
#titanic.Fare.fillna(titanic.Fare.median())

# %%
ser = titanic.groupby("Sex").Fare.transform('mean')
ser[:3]
# Out:
# 0    25.555619
# 1    44.479818
# 2    44.479818
# Name: Fare, dtype: float64

# %%
titanic["Fare"] =np.where(titanic["Fare"].isnull(), ser, titanic.Fare)

# %%
ser = titanic.groupby("Sex").Fare.transform('mean')
ser[:3]
# Out:
# 0    25.555619
# 1    44.479818
# 2    44.479818
# Name: Fare, dtype: float64

# %%
titanic["Fare"] =np.where(titanic["Fare"].isnull(), ser, titanic.Fare)

# %%
titanic.groupby(["Sex", "Pclass"]).Fare.mean().unstack()
# Out:
# Pclass           1          2          3
# Sex
# female  106.125798  21.970121  16.118810
# male     67.226127  19.741782  12.714387

# %%
titanic.plot()

# %%
titanic.groupby(["Sex", "Pclass"]).Fare.mean().unstack().plot(kind = "bar", figsize = [10,3], rot = 0)

# %%
ser = titanic.groupby(["Sex", "Pclass"]).Fare.transform("mean")
ser[:3]
# Out:
# 0     12.714387
# 1    106.125798
# 2     16.118810
# Name: Fare, dtype: float64

# %%
titanic["Fare"] =np.where(titanic["Fare"].isnull(), ser, titanic.Fare)

# %%
table = titanic.groupby("Embarked").mean()["Age"]

# %%
plt.bar(x = table.index, height = table)
# Out:
# <BarContainer object of 3 artists>

# %%
sns.violinplot(x = "Embarked", y = "Age", data = titanic )
#Violin plots are kde on both sides for Age for the group Embarked = S, and Age with Embarked = C, and age with Embarked = Q

# %%
sns.violinplot(x = titanic["Embarked"], y = titanic["Age"], order = ["C", "Q", "S"])

# %% [markdown]
# ### Cont + cont

# %%
plt.scatter(titanic["Age"], titanic["Fare"])

# %%
sns.lmplot(x = "Age", y = "Fare", data = titanic, fit_reg = True)

# %%
sns.pairplot(titanic[["Age", "Fare"]])#you can put all the continuous columns here

# %%
titanic[['Age', 'Fare']].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.095826
# Fare  0.095826  1.000000

# %%
corr = titanic.corr()

# %%
sns.heatmap(corr, annot = True )

# %% [markdown]
# ### Factor + Factor

# %%
titanic.groupby("Sex").mean()["Survived"].plot(kind = "bar")

# %%
#interpretation: sex is leading to a significant variance in the prob of survival
#so we select this feature - feature selection is an important branch of data science

# %%
sns.countplot("Sex", hue = "Survived", data = titanic)

# %%
#stacked bar plot
pd.crosstab(titanic.Sex, titanic.Survived).plot(kind = "bar", stacked = True)

# %%
#Beside bar plot
pd.crosstab(titanic.Sex, titanic.Survived).plot(kind = "bar", stacked = False)

# %%
#Factor plots
import warnings
warnings.filterwarnings(action = "ignore")
sns.factorplot("Embarked", "Survived", data = titanic)
plt.show()
#this also gives the 95% confidence interval for the prob of survival
#With 95% confidence we can say that a person with embarked = S, which prob of survival will be between 30% and 38%

# %% [markdown]
# ----

# %% [markdown]
# ### Subplots

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)#number of rows, number of columns, subplot number
titanic["Age"].plot(kind = "hist", colormap = "Greens_r") #using pandas library
plt.xlabel("Age")
plt.title("Histogram")

plt.subplot(1,2,2)
plt.hist(titanic["Fare"])
plt.xticks(np.arange(0,500,50), rotation = 40)

plt.show()

# %%
titanic.columns

# %%
cat_cols = ["Survived", "Pclass", "Sex", "Embarked"]

# %%
for idx, col in enumerate(cat_cols):
    print(idx, col,end = ", ")
# Out:
# 0 Survived, 1 Pclass, 2 Sex, 3 Embarked,

# %%
plt.figure(figsize = (10,5))
plt.subplots_adjust(hspace = .5, wspace = .5, left = .2)
for idx,col in enumerate(cat_cols):
    plt.subplot(2,2,idx+1) #2 rows and 2 columns is the division, idx+1 specifies the plot number
    sns.countplot(titanic[col])
#    plt.title(col)
plt.show()
